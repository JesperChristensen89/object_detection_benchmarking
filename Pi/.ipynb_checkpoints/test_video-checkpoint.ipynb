# %% [markdown]
# # Imports

# %%
from imutils.video import FPS
from imutils.video import FileVideoStream
import numpy as np
import argparse
import imutils
import time
import cv2
import os
from threading import Thread
import sys
import matplotlib.pyplot as plt
import multiprocessing
from multiprocessing import Queue, Pool
from IPython.display import clear_output
import warnings
warnings.filterwarnings('ignore')

# import the Queue class from Python 3
if sys.version_info >= (3, 0):
    from queue import Queue
# otherwise, import the Queue class for Python 2.7
else:
    from Queue import Queue

# %% [markdown]
# # Env setup

# %%
# This is needed to display the images.
# %matplotlib inline

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("models/research/")
sys.path.append("models/research/object_detection/")

PATH_TO_MODEL = "ssd_mobilenet_v1_coco_2017_11_17/frozen_inference_graph.pb"
PATH_TO_LABELS = "models/research/object_detection/data/mscoco_label_map.pbtxt"

NUM_CLASSES = 90

# %% [markdown]
# # Load label map

# %%
from utils import label_map_util

from utils import visualization_utils as vis_util

label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(label_map, max_num_classes=NUM_CLASSES,
                                                           use_display_name = True)
category_index = label_map_util.create_category_index(categories)

# %% [markdown]
# # Detection sections ....

# %%
def detect_objects(image_np, sess, detection_graph):
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    image_tensor = detection_graph.get_tensor_by_name('image_tensor:0')

    # Each box represents a part of the image where a particular object was detected.
    boxes = detection_graph.get_tensor_by_name('detection_boxes:0')

    # Each score represent how level of confidence for each of the objects.
    # Score is shown on the result image, together with the class label.
    scores = detection_graph.get_tensor_by_name('detection_scores:0')
    classes = detection_graph.get_tensor_by_name('detection_classes:0')
    num_detections = detection_graph.get_tensor_by_name('num_detections:0')

    # Actual detection.
    (boxes, scores, classes, num_detections) = sess.run(
        [boxes, scores, classes, num_detections],
        feed_dict={image_tensor: image_np_expanded})

    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        np.squeeze(boxes),
        np.squeeze(classes).astype(np.int32),
        np.squeeze(scores),
        category_index,
        use_normalized_coordinates=True,
        line_thickness=8)
    return image_np

# %%
def worker(input_q, output_q):
    # Load a (frozen) Tensorflow model into memory.
    detection_graph = tf.Graph()
    with detection_graph.as_default():
        od_graph_def = tf.GraphDef()
        with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
            serialized_graph = fid.read()
            od_graph_def.ParseFromString(serialized_graph)
            tf.import_graph_def(od_graph_def, name='')

        sess = tf.Session(graph=detection_graph)

    fps = FPS().start()
    while True:
        fps.update()
        frame = input_q.get()
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        output_q.put(detect_objects(frame_rgb, sess, detection_graph))

    fps.stop()
    sess.close()

# %%
logger = multiprocessing.log_to_stderr()
logger.setLevel(multiprocessing.SUBDEBUG)

input_q = Queue(maxsize=5)
output_q = Queue(maxsize=5)
pool = Pool(2, worker, (input_q, output_q))

print("[INFO] starting video file thread...")
video_capture = FileVideoStream("../data/test_video.mp4").start()

time.sleep(1.0)
#video_capture = WebcamVideoStream(src=args.video_source,
#                                  width=args.width,
#                                  height=args.height).start()
fps = FPS().start()

while video_capture.more():  # fps._numFrames < 120
    frame = video_capture.read()
    frame = imutils.resize(frame, width=480)
    input_q.put(frame)

    t = time.time()

    output_rgb = cv2.cvtColor(output_q.get(), cv2.COLOR_RGB2BGR)
    #cv2.imshow('Video', output_rgb)
    clear_output(wait=True)
    plt.imshow(output_rgb)
    plt.show()
    fps.update()

    print('[INFO] elapsed time: {:.2f}'.format(time.time() - t))

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

fps.stop()
print('[INFO] elapsed time (total): {:.2f}'.format(fps.elapsed()))
print('[INFO] approx. FPS: {:.2f}'.format(fps.fps()))

pool.terminate()
video_capture.stop()
#cv2.destroyAllWindows()
# Out:
# [DEBUG/MainProcess] created semlock with handle 1995526144
# [DEBUG/MainProcess] created semlock with handle 1995522048
# [DEBUG/MainProcess] created semlock with handle 1995517952
# [DEBUG/MainProcess] created semlock with handle 1995513856
# [DEBUG/MainProcess] added worker
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1] child process calling self.run()
# [INFO/PoolWorker-1] process shutting down
# [INFO/PoolWorker-2] child process calling self.run()
# [DEBUG/PoolWorker-1] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-2] process shutting down
# [DEBUG/PoolWorker-1] running the remaining "atexit" finalizers
# Process PoolWorker-1:
# [DEBUG/PoolWorker-2] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-2] running the remaining "atexit" finalizers
# Process PoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1] process exiting with exitcode 1
# [INFO/PoolWorker-2] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [INFO] starting video file thread...
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-3] child process calling self.run()
# [INFO/PoolWorker-3] process shutting down
# [INFO/PoolWorker-4] child process calling self.run()
# [DEBUG/PoolWorker-3] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-4] process shutting down
# [DEBUG/PoolWorker-3] running the remaining "atexit" finalizers
# [DEBUG/PoolWorker-4] running all "atexit" finalizers with priority >= 0
# Process PoolWorker-3:
# Traceback (most recent call last):
# [DEBUG/PoolWorker-4] running the remaining "atexit" finalizers
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Process PoolWorker-4:
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     detection_graph = tf.Graph()
#     self._target(*self._args, **self._kwargs)
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-3] process exiting with exitcode 1
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
#     detection_graph = tf.Graph()
# [INFO/PoolWorker-5] child process calling self.run()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-5] process shutting down
# [INFO/PoolWorker-4] process exiting with exitcode 1
# [DEBUG/PoolWorker-5] running all "atexit" finalizers with priority >= 0
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/PoolWorker-5] running the remaining "atexit" finalizers
# [DEBUG/MainProcess] added worker
# Process PoolWorker-5:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [INFO/PoolWorker-6] child process calling self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [INFO/PoolWorker-6] process shutting down
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# [DEBUG/PoolWorker-6] running all "atexit" finalizers with priority >= 0
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-5] process exiting with exitcode 1
# [DEBUG/PoolWorker-6] running the remaining "atexit" finalizers
# Process PoolWorker-6:
# Traceback (most recent call last):
# [DEBUG/MainProcess] cleaning up worker 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [DEBUG/MainProcess] added worker
#     self.run()
# [INFO/PoolWorker-7] child process calling self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [INFO/PoolWorker-7] process shutting down
# [DEBUG/PoolWorker-7] running all "atexit" finalizers with priority >= 0
#     detection_graph = tf.Graph()
# [DEBUG/PoolWorker-7] running the remaining "atexit" finalizers
# NameError: global name 'tf' is not defined
# Process PoolWorker-7:
# [INFO/PoolWorker-6] process exiting with exitcode 1
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] cleaning up worker 0
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-7] process exiting with exitcode 1
# [INFO/PoolWorker-8] child process calling self.run()
# [INFO/PoolWorker-8] process shutting down
# [DEBUG/PoolWorker-8] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-8] running the remaining "atexit" finalizers
# Process PoolWorker-8:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] cleaning up worker 0
#     detection_graph = tf.Graph()
# [DEBUG/MainProcess] added worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-8] process exiting with exitcode 1
# [INFO/PoolWorker-9] child process calling self.run()
# [DEBUG/MainProcess] cleaning up worker 0
# [INFO/PoolWorker-9] process shutting down
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-10] child process calling self.run()
# [DEBUG/PoolWorker-9] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-9] running the remaining "atexit" finalizers
# Process PoolWorker-9:
# Traceback (most recent call last):
# [INFO/PoolWorker-10] process shutting down
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [DEBUG/PoolWorker-10] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# [DEBUG/PoolWorker-10] running the remaining "atexit" finalizers
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
# Process PoolWorker-10:
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# Traceback (most recent call last):
#     detection_graph = tf.Graph()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# NameError: global name 'tf' is not defined
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# [INFO/PoolWorker-9] process exiting with exitcode 1
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
# [DEBUG/MainProcess] cleaning up worker 0
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# [DEBUG/MainProcess] added worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-11] child process calling self.run()
# [INFO/PoolWorker-11] process shutting down
# [INFO/PoolWorker-10] process exiting with exitcode 1
# [DEBUG/PoolWorker-11] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-11] running the remaining "atexit" finalizers
# Process PoolWorker-11:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
# [DEBUG/MainProcess] cleaning up worker 0
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-11] process exiting with exitcode 1
# [INFO/PoolWorker-12] child process calling self.run()
# [INFO/PoolWorker-12] process shutting down
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/PoolWorker-12] running all "atexit" finalizers with priority >= 0
# [DEBUG/MainProcess] added worker
# [DEBUG/PoolWorker-12] running the remaining "atexit" finalizers
# Process PoolWorker-12:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [INFO/PoolWorker-13] child process calling self.run()
#     self.run()
# [INFO/PoolWorker-13] process shutting down
# [DEBUG/PoolWorker-13] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [DEBUG/PoolWorker-13] running the remaining "atexit" finalizers
#     initializer(*initargs)
# Process PoolWorker-13:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     self.run()
#     detection_graph = tf.Graph()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# NameError: global name 'tf' is not defined
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [INFO/PoolWorker-12] process exiting with exitcode 1
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-13] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-14] child process calling self.run()
# [INFO/PoolWorker-14] process shutting down
# [DEBUG/PoolWorker-14] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-14] running the remaining "atexit" finalizers
# [DEBUG/MainProcess] cleaning up worker 0
# Process PoolWorker-14:
# [DEBUG/MainProcess] added worker
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [INFO/PoolWorker-15] child process calling self.run()
# [INFO/PoolWorker-15] process shutting down
#     self.run()
# [DEBUG/PoolWorker-15] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# [DEBUG/PoolWorker-15] running the remaining "atexit" finalizers
# Process PoolWorker-15:
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-14] process exiting with exitcode 1
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-15] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-17] child process calling self.run()
# [INFO/PoolWorker-16] child process calling self.run()
# [INFO/PoolWorker-16] process shutting down
# [DEBUG/PoolWorker-16] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-16] running the remaining "atexit" finalizers
# [INFO/PoolWorker-17] process shutting down
# [DEBUG/PoolWorker-17] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-17] running the remaining "atexit" finalizers
# Process PoolWorker-16:
# Traceback (most recent call last):
# Process PoolWorker-17:
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-17] process exiting with exitcode 1
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-16] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-18] child process calling self.run()
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-18] process shutting down
# [DEBUG/PoolWorker-18] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-18] running the remaining "atexit" finalizers
# [INFO/PoolWorker-19] child process calling self.run()
# [INFO/PoolWorker-19] process shutting down
# Process PoolWorker-18:
# [DEBUG/PoolWorker-19] running all "atexit" finalizers with priority >= 0
# Traceback (most recent call last):
# [DEBUG/PoolWorker-19] running the remaining "atexit" finalizers
# Process PoolWorker-19:
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-19] process exiting with exitcode 1
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-18] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-20] child process calling self.run()
# [DEBUG/PoolWorker-20] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-20] process shutting down
# [DEBUG/PoolWorker-20] running the remaining "atexit" finalizers
# Process PoolWorker-20:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [INFO/PoolWorker-21] child process calling self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [INFO/PoolWorker-21] process shutting down
# [DEBUG/PoolWorker-21] running all "atexit" finalizers with priority >= 0
#     initializer(*initargs)
# [DEBUG/PoolWorker-21] running the remaining "atexit" finalizers
# Process PoolWorker-21:
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# Traceback (most recent call last):
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [INFO/PoolWorker-20] process exiting with exitcode 1
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] cleaning up worker 0
#     detection_graph = tf.Graph()
# [DEBUG/MainProcess] added worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-21] process exiting with exitcode 1
# [INFO/PoolWorker-22] child process calling self.run()
# [INFO/PoolWorker-22] process shutting down
# [DEBUG/PoolWorker-22] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-22] running the remaining "atexit" finalizers
# Process PoolWorker-22:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# [DEBUG/MainProcess] cleaning up worker 0
# NameError: global name 'tf' is not defined
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-22] process exiting with exitcode 1
# [INFO/PoolWorker-23] child process calling self.run()
# [INFO/PoolWorker-23] process shutting down
# [DEBUG/PoolWorker-23] running all "atexit" finalizers with priority >= 0
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/PoolWorker-23] running the remaining "atexit" finalizers
# [DEBUG/MainProcess] added worker
# Process PoolWorker-23:
# [INFO/PoolWorker-24] child process calling self.run()
# [INFO/PoolWorker-24] process shutting down
# Traceback (most recent call last):
# [DEBUG/PoolWorker-24] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [DEBUG/PoolWorker-24] running the remaining "atexit" finalizers
#     self.run()
# Process PoolWorker-24:
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# Traceback (most recent call last):
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     self.run()
#     initializer(*initargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     initializer(*initargs)
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# [INFO/PoolWorker-23] process exiting with exitcode 1
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-24] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-25] child process calling self.run()
# [INFO/PoolWorker-25] process shutting down
# [DEBUG/PoolWorker-25] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-26] child process calling self.run()
# [DEBUG/PoolWorker-25] running the remaining "atexit" finalizers
# Process PoolWorker-25:
# Traceback (most recent call last):
# [INFO/PoolWorker-26] process shutting down
# [DEBUG/PoolWorker-26] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [DEBUG/PoolWorker-26] running the remaining "atexit" finalizers
# Process PoolWorker-26:
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     initializer(*initargs)
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [INFO/PoolWorker-26] process exiting with exitcode 1
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-25] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-27] child process calling self.run()
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-27] process shutting down
# [DEBUG/PoolWorker-27] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-27] running the remaining "atexit" finalizers
# [INFO/PoolWorker-28] child process calling self.run()
# Process PoolWorker-27:
# [INFO/PoolWorker-28] process shutting down
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# [DEBUG/PoolWorker-28] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-28] running the remaining "atexit" finalizers
#     self._target(*self._args, **self._kwargs)
# Process PoolWorker-28:
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#     initializer(*initargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     self._target(*self._args, **self._kwargs)
#     detection_graph = tf.Graph()
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-27] process exiting with exitcode 1
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-28] process exiting with exitcode 1
# [INFO/PoolWorker-29] child process calling self.run()
# [INFO/PoolWorker-29] process shutting down
# [DEBUG/PoolWorker-29] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-29] running the remaining "atexit" finalizers
# Process PoolWorker-29:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-29] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-30] child process calling self.run()
# [INFO/PoolWorker-30] process shutting down
# [DEBUG/PoolWorker-30] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-30] running the remaining "atexit" finalizers
# Process PoolWorker-30:
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [INFO/PoolWorker-31] child process calling self.run()
#     self.run()
# [INFO/PoolWorker-31] process shutting down
# [DEBUG/PoolWorker-31] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# [DEBUG/PoolWorker-31] running the remaining "atexit" finalizers
# Process PoolWorker-31:
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     initializer(*initargs)
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     detection_graph = tf.Graph()
#     initializer(*initargs)
# NameError: global name 'tf' is not defined
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [INFO/PoolWorker-30] process exiting with exitcode 1
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-31] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-32] child process calling self.run()
# [INFO/PoolWorker-33] child process calling self.run()
# [INFO/PoolWorker-32] process shutting down
# [DEBUG/PoolWorker-32] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-33] process shutting down
# [DEBUG/PoolWorker-33] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-32] running the remaining "atexit" finalizers
# [DEBUG/PoolWorker-33] running the remaining "atexit" finalizers
# Process PoolWorker-32:
# Process PoolWorker-33:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# Traceback (most recent call last):
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
#     detection_graph = tf.Graph()
# [INFO/PoolWorker-32] process exiting with exitcode 1
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-33] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-34] child process calling self.run()
# [INFO/PoolWorker-34] process shutting down
# [DEBUG/PoolWorker-34] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-34] running the remaining "atexit" finalizers
# Process PoolWorker-34:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-34] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-35] child process calling self.run()
# [INFO/PoolWorker-35] process shutting down
# [DEBUG/PoolWorker-35] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-35] running the remaining "atexit" finalizers
# Process PoolWorker-35:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
# [DEBUG/MainProcess] cleaning up worker 0
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] added worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-35] process exiting with exitcode 1
# [INFO/PoolWorker-36] child process calling self.run()
# [INFO/PoolWorker-36] process shutting down
# [DEBUG/PoolWorker-36] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-36] running the remaining "atexit" finalizers
# Process PoolWorker-36:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [DEBUG/MainProcess] cleaning up worker 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     initializer(*initargs)
#     detection_graph = tf.Graph()
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-36] process exiting with exitcode 1
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-37] child process calling self.run()
# [INFO/PoolWorker-37] process shutting down
# [DEBUG/PoolWorker-37] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-37] running the remaining "atexit" finalizers
# Process PoolWorker-37:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [DEBUG/MainProcess] cleaning up worker 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# [DEBUG/MainProcess] added worker
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [INFO/PoolWorker-38] child process calling self.run()
# [INFO/PoolWorker-38] process shutting down
#     initializer(*initargs)
# [DEBUG/PoolWorker-38] running all "atexit" finalizers with priority >= 0
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# Traceback (most recent call last):
# [DEBUG/PoolWorker-38] running the remaining "atexit" finalizers
# Process PoolWorker-38:
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     detection_graph = tf.Graph()
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# NameError: global name 'tf' is not defined
#     initializer(*initargs)
# [DEBUG/MainProcess] cleaning up worker 0
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [INFO/PoolWorker-37] process exiting with exitcode 1
#     detection_graph = tf.Graph()
# [DEBUG/MainProcess] added worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-38] process exiting with exitcode 1
# [INFO/PoolWorker-39] child process calling self.run()
# [INFO/PoolWorker-39] process shutting down
# [DEBUG/PoolWorker-39] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-39] running the remaining "atexit" finalizers
# Process PoolWorker-39:
# [DEBUG/MainProcess] cleaning up worker 0
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [DEBUG/MainProcess] added worker
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# [INFO/PoolWorker-40] child process calling self.run()
# [INFO/PoolWorker-40] process shutting down
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
# [DEBUG/PoolWorker-40] running all "atexit" finalizers with priority >= 0
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/PoolWorker-40] running the remaining "atexit" finalizers
# Process PoolWorker-40:
# Traceback (most recent call last):
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [INFO/PoolWorker-39] process exiting with exitcode 1
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-40] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-41] child process calling self.run()
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-41] process shutting down
# [DEBUG/PoolWorker-41] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-41] running the remaining "atexit" finalizers
# Process PoolWorker-41:
# Traceback (most recent call last):
# [INFO/PoolWorker-42] child process calling self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [INFO/PoolWorker-42] process shutting down
#     self.run()
# [DEBUG/PoolWorker-42] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-42] running the remaining "atexit" finalizers
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# Process PoolWorker-42:
# Traceback (most recent call last):
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     initializer(*initargs)
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# NameError: global name 'tf' is not defined
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-41] process exiting with exitcode 1
# [INFO/PoolWorker-42] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-43] child process calling self.run()
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-43] process shutting down
# [DEBUG/PoolWorker-43] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-43] running the remaining "atexit" finalizers
# [INFO/PoolWorker-44] child process calling self.run()
# [INFO/PoolWorker-44] process shutting down
# Process PoolWorker-43:
# Traceback (most recent call last):
# [DEBUG/PoolWorker-44] running all "atexit" finalizers with priority >= 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [DEBUG/PoolWorker-44] running the remaining "atexit" finalizers
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# Process PoolWorker-44:
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     initializer(*initargs)
#     self.run()
#     detection_graph = tf.Graph()
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# NameError: global name 'tf' is not defined
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [INFO/PoolWorker-43] process exiting with exitcode 1
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-44] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-45] child process calling self.run()
# [INFO/PoolWorker-45] process shutting down
# [DEBUG/PoolWorker-45] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-45] running the remaining "atexit" finalizers
# Process PoolWorker-45:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [DEBUG/MainProcess] cleaning up worker 0
# [INFO/PoolWorker-45] process exiting with exitcode 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-46] child process calling self.run()
# [DEBUG/PoolWorker-46] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-46] process shutting down
# [DEBUG/PoolWorker-46] running the remaining "atexit" finalizers
# Process PoolWorker-46:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-46] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-47] child process calling self.run()
# [INFO/PoolWorker-47] process shutting down
# [DEBUG/PoolWorker-47] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-47] running the remaining "atexit" finalizers
# Process PoolWorker-47:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-47] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-48] child process calling self.run()
# [DEBUG/PoolWorker-48] running all "atexit" finalizers with priority >= 0
# [INFO/PoolWorker-48] process shutting down
# [DEBUG/PoolWorker-48] running the remaining "atexit" finalizers
# Process PoolWorker-48:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-48] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-49] child process calling self.run()
# [INFO/PoolWorker-49] process shutting down
# [DEBUG/PoolWorker-49] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-49] running the remaining "atexit" finalizers
# Process PoolWorker-49:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-49] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-50] child process calling self.run()
# [INFO/PoolWorker-50] process shutting down
# [DEBUG/PoolWorker-50] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-50] running the remaining "atexit" finalizers
# Process PoolWorker-50:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-50] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 0
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-51] child process calling self.run()
# [INFO/PoolWorker-51] process shutting down
# [DEBUG/PoolWorker-51] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-51] running the remaining "atexit" finalizers
# Process PoolWorker-51:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# [DEBUG/MainProcess] cleaning up worker 0
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [DEBUG/MainProcess] added worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# [INFO/PoolWorker-52] child process calling self.run()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-52] process shutting down
# [INFO/PoolWorker-51] process exiting with exitcode 1
# [DEBUG/PoolWorker-52] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-52] running the remaining "atexit" finalizers
# Traceback (most recent call last):
# Process PoolWorker-52:
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# [DEBUG/MainProcess] cleaning up worker 0
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
# [DEBUG/MainProcess] added worker
#     initializer(*initargs)
#     detection_graph = tf.Graph()
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-52] process exiting with exitcode 1
# [INFO/PoolWorker-53] child process calling self.run()
# [INFO/PoolWorker-53] process shutting down
# [DEBUG/PoolWorker-53] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-53] running the remaining "atexit" finalizers
# Process PoolWorker-53:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
# [DEBUG/MainProcess] cleaning up worker 0
#     self.run()
# [DEBUG/MainProcess] added worker
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-53] process exiting with exitcode 1
# [INFO/PoolWorker-54] child process calling self.run()
# [INFO/PoolWorker-54] process shutting down
# [DEBUG/PoolWorker-54] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-54] running the remaining "atexit" finalizers
# Process PoolWorker-54:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
# [DEBUG/MainProcess] cleaning up worker 0
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] added worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-54] process exiting with exitcode 1
# [INFO/PoolWorker-55] child process calling self.run()
# [INFO/PoolWorker-55] process shutting down
# [DEBUG/PoolWorker-55] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-55] running the remaining "atexit" finalizers
# Process PoolWorker-55:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# [DEBUG/MainProcess] cleaning up worker 0
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
# [DEBUG/MainProcess] added worker
#     detection_graph = tf.Graph()
# [INFO/PoolWorker-56] child process calling self.run()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-56] process shutting down
# [INFO/PoolWorker-55] process exiting with exitcode 1
# ...
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1946] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1947] child process calling self.run()
# [INFO/PoolWorker-1947] process shutting down
# [DEBUG/PoolWorker-1947] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1947] running the remaining "atexit" finalizers
# Process PoolWorker-1947:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1947] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1948] child process calling self.run()
# [INFO/PoolWorker-1948] process shutting down
# [DEBUG/PoolWorker-1948] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1948] running the remaining "atexit" finalizers
# Process PoolWorker-1948:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1948] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1949] child process calling self.run()
# [INFO/PoolWorker-1949] process shutting down
# [DEBUG/PoolWorker-1949] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1949] running the remaining "atexit" finalizers
# Process PoolWorker-1949:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1949] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1950] child process calling self.run()
# [INFO/PoolWorker-1950] process shutting down
# [DEBUG/PoolWorker-1950] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1950] running the remaining "atexit" finalizers
# Process PoolWorker-1950:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1950] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1951] child process calling self.run()
# [INFO/PoolWorker-1951] process shutting down
# [DEBUG/PoolWorker-1951] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1951] running the remaining "atexit" finalizers
# Process PoolWorker-1951:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1951] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1952] child process calling self.run()
# [INFO/PoolWorker-1952] process shutting down
# [DEBUG/PoolWorker-1952] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1952] running the remaining "atexit" finalizers
# Process PoolWorker-1952:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1952] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1953] child process calling self.run()
# [INFO/PoolWorker-1953] process shutting down
# [DEBUG/PoolWorker-1953] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1953] running the remaining "atexit" finalizers
# Process PoolWorker-1953:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1953] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1954] child process calling self.run()
# [INFO/PoolWorker-1954] process shutting down
# [DEBUG/PoolWorker-1954] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1954] running the remaining "atexit" finalizers
# Process PoolWorker-1954:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1954] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1955] child process calling self.run()
# [INFO/PoolWorker-1955] process shutting down
# [DEBUG/PoolWorker-1955] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1955] running the remaining "atexit" finalizers
# Process PoolWorker-1955:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1955] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1956] child process calling self.run()
# [INFO/PoolWorker-1956] process shutting down
# [DEBUG/PoolWorker-1956] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1956] running the remaining "atexit" finalizers
# Process PoolWorker-1956:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1956] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1957] child process calling self.run()
# [INFO/PoolWorker-1957] process shutting down
# [DEBUG/PoolWorker-1957] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1957] running the remaining "atexit" finalizers
# Process PoolWorker-1957:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1957] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1958] child process calling self.run()
# [INFO/PoolWorker-1958] process shutting down
# [DEBUG/PoolWorker-1958] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1958] running the remaining "atexit" finalizers
# Process PoolWorker-1958:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1958] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1959] child process calling self.run()
# [INFO/PoolWorker-1959] process shutting down
# [DEBUG/PoolWorker-1959] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1959] running the remaining "atexit" finalizers
# Process PoolWorker-1959:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1959] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1960] child process calling self.run()
# [INFO/PoolWorker-1960] process shutting down
# [DEBUG/PoolWorker-1960] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1960] running the remaining "atexit" finalizers
# Process PoolWorker-1960:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1960] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1961] child process calling self.run()
# [INFO/PoolWorker-1961] process shutting down
# [DEBUG/PoolWorker-1961] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1961] running the remaining "atexit" finalizers
# Process PoolWorker-1961:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1961] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1962] child process calling self.run()
# [INFO/PoolWorker-1962] process shutting down
# [DEBUG/PoolWorker-1962] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1962] running the remaining "atexit" finalizers
# Process PoolWorker-1962:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1962] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1963] child process calling self.run()
# [INFO/PoolWorker-1963] process shutting down
# [DEBUG/PoolWorker-1963] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1963] running the remaining "atexit" finalizers
# Process PoolWorker-1963:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker
#     initializer(*initargs)
#   File "<ipython-input-5-de59c3e26f3b>", line 3, in worker
#     detection_graph = tf.Graph()
# NameError: global name 'tf' is not defined
# [INFO/PoolWorker-1963] process exiting with exitcode 1
# [DEBUG/MainProcess] cleaning up worker 1
# [DEBUG/MainProcess] added worker
# [INFO/PoolWorker-1964] child process calling self.run()
# [INFO/PoolWorker-1964] process shutting down
# [DEBUG/PoolWorker-1964] running all "atexit" finalizers with priority >= 0
# [DEBUG/PoolWorker-1964] running the remaining "atexit" finalizers
# Process PoolWorker-1964:
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 97, in worker

# %% [markdown]
# # Process video

# %%
# start the file video stream thread and allow the buffer to
# start to fill
print("[INFO] starting video file thread...")
fvs = FileVideoStream("../data/test_video.mp4").start()
time.sleep(1.0)
 
# start the FPS timer
fps = FPS().start()
framecnt = 0
# loop over frames from the video file stream
while not fvs.stopped:
    framecnt = framecnt + 1
    # grab the frame from the threaded video file stream, resize
    # it, and convert it to grayscale (while still retaining 3
    # channels)
    frame = fvs.read()
    #frame = imutils.resize(frame, width=450)
    #frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #frame = np.dstack([frame, frame, frame])

    # display the size of the queue on the frame
    #cv2.putText(frame, "Queue Size: {}".format(fvs.Q.qsize()),
    #    (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)	

    # show the frame and update the FPS counter
    #cv2.imshow("Frame", frame)
    #cv2.waitKey(1)
    #clear_output(wait=True)
    #plt.imshow(frame)
    #plt.show()
    fps.update()
    #time.sleep(2)

# stop the timer and display FPS information
fps.stop()
print("[INFO] elasped time: {:.2f}".format(fps.elapsed()))
print("[INFO] approx. FPS: {:.2f}".format(fps.fps()))
print("[INFO] Frames: {:.2f}".format(framecnt))
 
# do a bit of cleanup
#cv2.destroyAllWindows()
fps.stop()
